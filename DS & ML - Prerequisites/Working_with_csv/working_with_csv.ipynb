# %%
import pandas as pd

# %%
pd.read_csv('deliveries.csv/deliveries.csv').head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
pd.read_csv('deliveries.csv/deliveries.csv',converters={'bowling_team':lambda x: 'RCB' if x=='Royal Challengers Bangalore' else x}).head()
# Out:
#    match_id  inning           batting_team bowling_team  over  ball  \
# 0    335982       1  Kolkata Knight Riders          RCB     0     1
# 1    335982       1  Kolkata Knight Riders          RCB     0     2
# 2    335982       1  Kolkata Knight Riders          RCB     0     3
# 3    335982       1  Kolkata Knight Riders          RCB     0     4
# 4    335982       1  Kolkata Knight Riders          RCB     0     5
#
#         batter   bowler  non_striker  batsman_runs  extra_runs  total_runs  \
# 0   SC Ganguly  P Kumar  BB McCullum             0           1           1
# 1  BB McCullum  P Kumar   SC Ganguly             0           0           0
# 2  BB McCullum  P Kumar   SC Ganguly             0           1           1
# 3  BB McCullum  P Kumar   SC Ganguly             0           0           0
# 4  BB McCullum  P Kumar   SC Ganguly             0           0           0
#
#   extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
 pd.read_csv('deliveries.csv/deliveries.csv',na_values={'extra_runs':0}).head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0         1.0
# 1     2  BB McCullum  P Kumar   SC Ganguly             0         NaN
# 2     3  BB McCullum  P Kumar   SC Ganguly             0         1.0
# 3     4  BB McCullum  P Kumar   SC Ganguly             0         NaN
# 4     5  BB McCullum  P Kumar   SC Ganguly             0         NaN
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
pd.read_csv('deliveries.csv/deliveries.csv',index_col='match_id').tail()
# Out:
#           inning           batting_team         bowling_team  over  ball  \
# match_id
# 1426312        2  Kolkata Knight Riders  Sunrisers Hyderabad     9     5
# 1426312        2  Kolkata Knight Riders  Sunrisers Hyderabad     9     6
# 1426312        2  Kolkata Knight Riders  Sunrisers Hyderabad    10     1
# 1426312        2  Kolkata Knight Riders  Sunrisers Hyderabad    10     2
# 1426312        2  Kolkata Knight Riders  Sunrisers Hyderabad    10     3
#
#            batter         bowler non_striker  batsman_runs  extra_runs  \
# match_id
# 1426312   SS Iyer     AK Markram     VR Iyer             1           0
# 1426312   VR Iyer     AK Markram     SS Iyer             1           0
# 1426312   VR Iyer  Shahbaz Ahmed     SS Iyer             1           0
# 1426312   SS Iyer  Shahbaz Ahmed     VR Iyer             1           0
# 1426312   VR Iyer  Shahbaz Ahmed     SS Iyer             1           0
#
# ...

# %%
pd.read_csv('deliveries.csv/deliveries.csv',nrows=1000).shape
# Out:
# (1000, 17)

# %%
pd.read_csv('deliveries.csv/deliveries.csv',skiprows = lambda x : True if x%2==0 else False).shape
# Out:
# (130459, 17)

# %%
pd.read_csv('deliveries.csv/deliveries.csv',usecols=[1,2,3,6,7,13,14]).head()
# Out:
#    inning           batting_team                 bowling_team       batter  \
# 0       1  Kolkata Knight Riders  Royal Challengers Bangalore   SC Ganguly
# 1       1  Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 2       1  Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 3       1  Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 4       1  Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
#
#     bowler  is_wicket player_dismissed
# 0  P Kumar          0              NaN
# 1  P Kumar          0              NaN
# 2  P Kumar          0              NaN
# 3  P Kumar          0              NaN
# 4  P Kumar          0              NaN

# %%
pd.read_csv('deliveries.csv/deliveries.csv',usecols=[1,2,3,6,7,13,14],names=['Innings','Bat_Team','Bowl_Team','Batsman','Bowler','Is_wicket','Dismissed_player'],header=0).head()
# Out:
#    Innings               Bat_Team                    Bowl_Team      Batsman  \
# 0        1  Kolkata Knight Riders  Royal Challengers Bangalore   SC Ganguly
# 1        1  Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 2        1  Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 3        1  Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 4        1  Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
#
#     Bowler  Is_wicket Dismissed_player
# 0  P Kumar          0              NaN
# 1  P Kumar          0              NaN
# 2  P Kumar          0              NaN
# 3  P Kumar          0              NaN
# 4  P Kumar          0              NaN

# %%
dfs = pd.read_csv('deliveries.csv/deliveries.csv',chunksize=50000)

# %%
for df in dfs :
    print(df.shape)
# Out:
# (50000, 17)
# (50000, 17)
# (50000, 17)
# (50000, 17)
# (50000, 17)
# (10920, 17)
